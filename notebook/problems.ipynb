# %% [markdown]
# # Probability Distribution Problems

# %% [markdown]
# **Binomial Distribution**
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either Head or Tails.

# %%
# Probability functions, density and distribution

def dbinom(x,size,prob=0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    from scipy.stats import binom
    result=binom.pmf(k=x,n=size,p=prob,loc=0)
    return result

def pbinom(q,size,prob=0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    from scipy.stats import binom
    result=binom.cdf(k=q,n=size,p=prob,loc=0)
    return result

def qbinom(p, size, prob=0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    from scipy.stats import binom
    result=binom.ppf(q=p,n=size,p=prob,loc=0)
    return result

def rbinom(n,size,prob=0.5):
    """
    Generates random variables from the binomial distribution
    """
    from scipy.stats import binom
    result=binom.rvs(n=size,p=prob,size=n)
    return result

# %%
dbinom(2, size = 10, prob = 0.2) #Probability that a binomial (10,0.2) takes the value 2,
pbinom(2, size = 10, prob = 0.2) #Probability that a binomial (10,0.2) will take a value less than 2
qbinom(0.9, size = 10, prob = 0.2) # what value of a binomial (10,0.2) has a cumulative probability of 0.9?
rbinom(2000, size = 10, prob = 0.2) # generate 2000 random values from a binomial distribution (10,0.2)
# Out:
# array([1, 1, 1, ..., 1, 4, 2])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Discrete distributions
xs = np.arange( 1, 11 )
ys = dbinom(xs,size=10,prob=0.5) # compute the shape of the distribution
plt.plot( xs, ys, 'o' )   # plot circles...
plt.vlines( xs, 0, ys )   # ...and lines
plt.ylim( bottom=0 )      # ensure sensible bottom border
plt.title('Probability function binomial distribution')
plt.show()

# %% [markdown]
# Exercise 1: Create the same functions but for the normal and uniform distribution.

# %%
#######NORMAL DISTRIBUTION#######
#Code here
def dnormal(x,mean=0,sd=1):
    #Calculates the density of the Normal distribution
    
    from scipy.stats import norm
    result=norm.pdf(x,loc=mean,scale=sd)
    return result


def pnormal(x,mean=0,sd=1):
    """
    Calculates the cumulative of the normal distribution
    """
    from scipy.stats import norm
    result=norm.cdf(x,loc=mean,scale=sd)
    return result

def qnormal(p, mean=0,sd=1):
    """
    Calculates the quantile function from the normal distribution
    Percent point function (inverse of cdf — percentiles).
    """
    from scipy.stats import norm
    result=norm.ppf(p,loc=mean,scale=sd)
    return result

def rnormal(mean=0,sd=1,size=1):
    """
    Generates random variables from the normal distribution
    """
    from scipy.stats import norm
    result=norm.rvs(loc=mean,scale=sd, size=size)
    return result

# %%
import numpy as np
x = np.linspace(-3,3,100) 
#The mean determines where the curve is centered. 
#Increasing the mean moves the curve right, while decreasing it moves the curve left.
#The standard deviation stretches or squeezes the curve. 
#A small standard deviation results in a narrow curve, while a large standard deviation leads to a wide curve.

print("Density",dnormal(x,mean=0,sd=1)) #density of Standard normal distribution (mean=0, standar Desviation=1)
print("Probability",pnormal(x,mean=0,sd=1))
print("Value of 0.95",qnormal(0.95, mean=0,sd=1)) # what value of a normal (0,1) has a cumulative probability of 0.95?
print("Random Values",rnormal(mean=0,sd=1,size=5)) # generate 5 random values from a normal distribution
# Out:
# Density [0.00443185 0.00530579 0.00632878 0.00752133 0.00890582 0.0105065
#  0.01234943 0.01446241 0.01687483 0.01961746 0.02272223 0.02622189
#  0.03014961 0.03453857 0.03942137 0.0448295  0.05079264 0.05733801
#  0.06448952 0.07226707 0.08068571 0.08975477 0.09947714 0.10984842
#  0.12085626 0.13247967 0.14468855 0.15744319 0.17069405 0.18438164
#  0.1984366  0.21277993 0.22732351 0.24197072 0.2566174  0.27115285
#  0.28546117 0.29942268 0.31291556 0.3258175  0.33800759 0.34936814
#  0.35978656 0.36915722 0.37738323 0.38437808 0.3900672  0.39438923
#  0.39729716 0.39875915 0.39875915 0.39729716 0.39438923 0.3900672
#  0.38437808 0.37738323 0.36915722 0.35978656 0.34936814 0.33800759
#  0.3258175  0.31291556 0.29942268 0.28546117 0.27115285 0.2566174
#  0.24197072 0.22732351 0.21277993 0.1984366  0.18438164 0.17069405
#  0.15744319 0.14468855 0.13247967 0.12085626 0.10984842 0.09947714
#  0.08975477 0.08068571 0.07226707 0.06448952 0.05733801 0.05079264
#  0.0448295  0.03942137 0.03453857 0.03014961 0.02622189 0.02272223
#  0.01961746 0.01687483 0.01446241 0.01234943 0.0105065  0.00890582
#  0.00752133 0.00632878 0.00530579 0.00443185]
# Probability [0.0013499  0.00164427 0.00199603 0.00241482 0.00291159 0.00349868
#  0.00418999 0.00500104 0.00594906 0.00705314 0.00833425 0.00981533
#  0.01152131 0.01347915 0.01571778 0.01826811 0.02116287 0.02443656
#  0.02812518 0.03226612 0.03689778 0.04205935 0.04779035 0.0541303
#  0.06111818 0.06879198 0.07718815 0.08634102 0.09628221 0.10704004
#  0.11863893 0.13109879 0.14443448 0.15865525 0.17376426 0.18975815
#  0.20662669 0.2243525  0.24291088 0.26226972 0.28238953 0.30322357
#  0.32471814 0.34681289 0.36944134 0.39253143 0.41600624 0.43978468
#  0.46378241 0.48791269 0.51208731 0.53621759 0.56021532 0.58399376
#  0.60746857 0.63055866 0.65318711 0.67528186 0.69677643 0.71761047
#  0.73773028 0.75708912 0.7756475  0.79337331 0.81024185 0.82623574
#  0.84134475 0.85556552 0.86890121 0.88136107 0.89295996 0.90371779
#  0.91365898 0.92281185 0.93120802 0.93888182 0.9458697  0.95220965
#  0.95794065 0.96310222 0.96773388 0.97187482 0.97556344 0.97883713
#  0.98173189 0.98428222 0.98652085 0.98847869 0.99018467 0.99166575
#  0.99294686 0.99405094 0.99499896 0.99581001 0.99650132 0.99708841
#  0.99758518 0.99800397 0.99835573 0.9986501 ]
# Value of 0.95 1.6448536269514722
# Random Values [0.43465526 0.70898985 1.3727123  0.62249482 1.14458572]

# %%
import numpy as np
import matplotlib.pyplot as plt


rv=rnormal(5,10,5) #mean,deriv std,size
print(rv)

# continue distributions
x = np.linspace(-3,3,100) 
plt.plot( x, dnormal(x))   
plt.title('Density of Normal distribution')
plt.show()
# Out:
# [ -1.45285227 -10.39720224   7.34592825  -1.63290668  15.10505065]

# %%
plt.plot(x,pnormal(x))
plt.title('Probability normal distribution')
plt.show()

# %%
qnormal(0.95)
# Out:
# 1.6448536269514722

# %%
#######UNIFORM DISTRIBUTION#######
#Code here
def duniform(x,a=0,b=1):
    #Calculates the density of the Normal distribution
    
    from scipy.stats import uniform 
    result=uniform.pdf(x,loc=a,scale=b)
    return result


def puniform(x,a=0,b=1):
    """
    Calculates the cumulative of the normal distribution
    """
    from scipy.stats import uniform 
    result=uniform.cdf(x,loc=a,scale=b)
    return result

def quniform(p, a=0,b=1):
    """
    Calculates the quantile function from the normal distribution
    Percent point function (inverse of cdf — percentiles).
    """
    from scipy.stats import uniform 
    result=uniform.ppf(p,loc=a,scale=b)
    return result

def runiform(a,b,size=1):
    """
    Generates random variables from the uniform distribution
    """
    from scipy.stats import uniform 
    result=uniform.rvs(a,b, size=size)
    return result

# %%
x = np.linspace(0, 5, 100) 
puniform(x,0,1)

import matplotlib.pyplot as plt

plt.plot(x,puniform(x))
plt.title('Probability uniform distribution')
plt.show()

# %%
a,b=0,1
runiform(a,b,5)
# Out:
# array([0.53761097, 0.75120228, 0.21582416, 0.21484861, 0.89448873])

# %%
x = np.linspace(0, 5, 100) 
duniform(x,0,1)

import matplotlib.pyplot as plt

plt.plot(x,duniform(x))
plt.title('Density uniform distribution')
plt.show()

# %%
quniform(0.95,0,1)
# Out:
# 0.95
